# %% [markdown]
# # Características de Python

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
"Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
print("Hola")
print("Mundo")
# Out:
# Hola
# Mundo

# %%
print("Hola", end = " ")
print("Mundo")
# Out:
# Hola Mundo

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
variable = "texto"
print(type(variable))
variable = 123
print(type(variable))
# Out:
# <class 'str'>
# <class 'int'>

# %%
peras = 1
manzanas = 3
naranjas = 5
melocotones = 8
melones = 2
sandias = 1
fresas = 3

# %%
peras + manzanas + naranjas + melocotones +\
    fresas + sandias
# Out:
# 21

# %%
(peras + manzanas + naranjas + melocotones +
    fresas + sandias)
# Out:
# 21

# %%
condicion = True
if condicion:
    print("La condición se cumple")
# Out:
# La condición se cumple

# %%
meses_inversion = 8
meses_inversion_tv = meses_inversion
meses_inversion = 10
meses_inversion_tv
# Out:
# 8

# %% [markdown]
# # Módulos

# %%
# %load_ext autoreload
# %autoreload 2
import modulo
modulo.divide_numeros(4,2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 import modulo
#       4 modulo.divide_numeros(4,2)
#
# ModuleNotFoundError: No module named 'modulo'

# %%
from modulo import divide_numeros
divide_numeros(8,2)
# Out:
# 4.0

# %%
from modulo import *
divide_numeros(8,2)
# Out:
# 4.0

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ## Variable

# %%
meses_inversion_TV = 8
meses_inversion_TV
# Out:
# 8

# %% [markdown]
# ## Lógicos

# %%
booleano = True
booleano
# Out:
# True

# %%
type(booleano)
# Out:
# bool

# %%
booleano + booleano
# Out:
# 2

# %% [markdown]
# ## Números

# %%
2+2
# Out:
# 4

# %%
2-2
# Out:
# 0

# %%
2.5*2.5
# Out:
# 6.25

# %%
8/5
# Out:
# 1.6

# %%
8//5
# Out:
# 1

# %%
8%5
# Out:
# 3

# %%
2**3
# Out:
# 8

# %%
abs(-5)
# Out:
# 5

# %%
int(5.4)
# Out:
# 5

# %%
float(3)
# Out:
# 3.0

# %%
dividendo = 8
divisor = 3
division = dividendo/divisor
print(division)
print(type(division))
# Out:
# 2.6666666666666665
# <class 'float'>

# %% [markdown]
# ## Secuencias

# %%
3 in [1,2,3]
# Out:
# True

# %%
5 not in [1,2,3]
# Out:
# True

# %%
['a', 'b'] + ['c']
# Out:
# ['a', 'b', 'c']

# %%
['a', 'b'] *2
# Out:
# ['a', 'b', 'a', 'b']

# %%
(1,2,3,4,5,6)[0]
# Out:
# 1

# %%
(1,2,3,4,5,6)[0:4]
# Out:
# (1, 2, 3, 4)

# %%
(1,2,3,4,5,6)[0:4:2]
# Out:
# (1, 3)

# %%
max(['a','b', 'c'])
# Out:
# 'c'

# %%
secuencia = ['a','b','c','d','e']
secuencia[0]
# Out:
# 'a'

# %%
secuencia[0:3]
# Out:
# ['a', 'b', 'c']

# %%
secuencia[0:]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
secuencia[-2]
# Out:
# 'd'

# %%
secuencia_numerica = [1,2,3,4,5,6,7,8]
secuencia_numerica[2:6:2]
# Out:
# [3, 5]

# %%
secuencia[::-1]
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %% [markdown]
# ## Texto

# %%
"hola mundo"
# Out:
# 'hola mundo'

# %%
cadena = 'hola mundo'
cadena
# Out:
# 'hola mundo'

# %%
cadena[1]
# Out:
# 'o'

# %%
cadena[0:4]
# Out:
# 'hola'

# %%
cadena2 = cadena[0] + 'a' + cadena[2:]
cadena2
# Out:
# 'hala mundo'

# %%
cadena[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-791ffba32137> in <module>
# ----> 1 cadena[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
'comillas simples' + "comillas dobles" +\
"""comillas triples 
con saltos de línea 
"""
# Out:
# 'comillas simplescomillas doblescomillas triples \ncon saltos de línea \n'

# %%
saludo = "hola"
destinatario = "mundo"
f"{saludo.capitalize()} {destinatario.upper()}!"
# Out:
# 'Hola MUNDO!'

# %%
cadena.

# %%
# ?cadena.capitalize

# %%
str(5)
# Out:
# '5'

# %% [markdown]
# ## None

# %%
meses_inversion_tv = None
type(meses_inversion_tv)
# Out:
# NoneType

# %% [markdown]
# # Operaciones de comparación

# %%
True >= False
# Out:
# True

# %%
True is None
# Out:
# False

# %%
'a' == "A"
# Out:
# False

# %%
'a' > "A"
# Out:
# True

# %%
"A"> 'a'
# Out:
# False

# %%
"b" > "A"
# Out:
# True

# %% [markdown]
# ## Precedencia de operadores

# %%
2 / 3 * 5
# Out:
# 3.333333333333333

# %%
(2/3)*5
# Out:
# 3.333333333333333

# %%
2 * 3 / 5
# Out:
# 1.2

# %%
(2*3)/5
# Out:
# 1.2

# %%
3 < 5 < 7.8
# Out:
# True

# %%
'a' != 'b' > 'c'
# Out:
# False

# %% [markdown]
# ## Para saber más: is

# %%
a = 3
print(id(a))
# Out:
# 140733000823696

# %%
b = 3
print(id(b))
# Out:
# 140733000823696

# %%
lista_a = [1, 2]
lista_b = [1, 2]
print(id(lista_a))
print(id(lista_b))
print(lista_a == lista_b)
print(lista_a is lista_b)
# Out:
# 1989353762376
# 1989353829128
# True
# False

# %% [markdown]
# # Test Autoevaluable

# %%
variable = 1
variable = "Texto"

# %% [markdown]
# Cuidado, el >= tiene más prioridad que and!

# %%
cadena = "cadena"
cadena[1] = "C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-a9cc22e23318> in <module>
#       1 cadena = "cadena"
# ----> 2 cadena[1] = "C"
#
# TypeError: 'str' object does not support item assignment

# %%
2 * 3 / 5 >= True and False
# Out:
# False

# %%
(((2 * 3) / 5) >= True) and False
# Out:
# False

# %%
((2 * 3) / 5) >= (True and False)
# Out:
# True
