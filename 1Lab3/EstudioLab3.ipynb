# %% [markdown]
# Alumno: Sergio Santamaría Trueba

# %%
# En este lab vamos a trabajar con la preparación de los datos, es decir, con la limpieza y transformación de los datos
# para que puedan ser utilizados en modelos de aprendizaje automático.

print("Hola, este es el Lab 3 de preparación de datos")
# Out:
# Hola, este es el Lab 3 de preparación de datos

# %%
# Vamos a empezar a trabajar con branch dev
